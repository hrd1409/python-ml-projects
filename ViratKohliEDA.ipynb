# %% [markdown]
# <a href="https://colab.research.google.com/github/hrd1409/python-ml-projects/blob/master/ViratKohliEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Loading Dataset

# %%
data=pd.read_csv("/content/ViratKohli.76centuries.csv")

# %% [markdown]
# Data Exploration and processing

# %%
data.head()
# Out:
#    Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0    116         Out     Australia              6     2          NaN
# 1    103         Out   New Zealand              5     2          NaN
# 2    103         Out       England              5     2          NaN
# 3    107         Out     Australia              5     2          NaN
# 4    119         Out  South Africa              4     1          NaN
#
#                                   Venue        Column1   H/A        Date  \
# 0                         Adelaide Oval       Adelaide  Away  24-01-2012
# 1                M. Chinnaswamy Stadium      Bangalore  Home  31-08-2012
# 2  Vidarbha Cricket Association Stadium         Nagpur  Home  13-12-2012
# 3             M. A. Chidambaram Stadium        Chennai  Home  22-02-2013
# 4                     Wanderers Stadium   Johannesburg  Away  18-12-2013
#
#   Result Format Man of the Match Captain
# 0   Lost   Test               No      No
# ...

# %%
data.tail()
# Out:
#     Score Out/Not Out      Against  Batting Order  Inn.  Strike Rate  \
# 71    113         Out   Bangladesh              3     1       124.80
# 72    113         Out    Sri Lanka              3     1       129.89
# 73    166     Not Out    Sri Lanka              3     1       150.91
# 74    186         Out    Australia              4     1        51.09
# 75    121         Out  West Indies              4     1        58.74
#
#                     Venue           Column1   H/A        Date Result Format  \
# 71  Zohur Ahmed Chaudhary        Chittagong  Away  10/12/2022    Won    ODI
# 72              Barsapara          Guwahati  Home   10/1/2023    Won    ODI
# 73            Green field  Thiruvanantpuram  Home   15/1/2023    Won    ODI
# 74                 Motera         Ahemdabad  Home   12/3/2023  Drawn   Test
# 75      Queen's Park Oval     Port of Spain  Away   21/7/2023  Drawn   Test
#
#    Man of the Match Captain
# 71               No      No
# 72              Yes      No
# ...

# %%
data.isnull().sum()
# Out:
# Score                0
# Out/Not Out          0
# Against              0
# Batting Order        0
# Inn.                 0
# Strike Rate         27
# Venue                0
# Column1              0
# H/A                  0
# Date                 0
# Result               0
# Format               0
# Man of the Match     0
# Captain              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Score             76 non-null     int64
#  1   Out/Not Out       76 non-null     object
#  2   Against           76 non-null     object
#  3   Batting Order     76 non-null     int64
#  4   Inn.              76 non-null     int64
#  5   Strike Rate       49 non-null     float64
#  6   Venue             76 non-null     object
#  7   Column1           76 non-null     object
#  8   H/A               76 non-null     object
#  9   Date              76 non-null     object
#  10  Result            76 non-null     object
#  11  Format            76 non-null     object
#  12  Man of the Match  76 non-null     object
#  13  Captain           76 non-null     object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 8.4+ KB

# %%
data.describe()
# Out:
#             Score  Batting Order       Inn.  Strike Rate
# count   76.000000      76.000000  76.000000    49.000000
# mean   132.644737       3.513158   1.684211   112.903878
# std     35.619734       0.702252   0.677457    27.430056
# min    100.000000       1.000000   1.000000    51.090000
# 25%    107.000000       3.000000   1.000000    96.520000
# 50%    119.500000       3.000000   2.000000   110.310000
# 75%    140.250000       4.000000   2.000000   122.890000
# max    254.000000       6.000000   4.000000   200.000000

# %%
data.size
# Out:
# 1064

# %%
data.shape
# Out:
# (76, 14)

# %%
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 71    113         Out    Bangladesh              3     1       124.80
# 72    113         Out     Sri Lanka              3     1       129.89
# 73    166     Not Out     Sri Lanka              3     1       150.91
# 74    186         Out     Australia              4     1        51.09
# 75    121         Out   West Indies              4     1        58.74
#
#                                    Venue           Column1   H/A        Date  \
# ...

# %%
data.sort_values(by='Score',inplace=True)

# %%
data.head(5)
# Out:
#     Score Out/Not Out      Against  Batting Order  Inn.  Strike Rate  \
# 31    100     Not Out   Bangladesh              4     1       120.48
# 42    100     Not Out    Australia              3     2       192.30
# 28    102     Not Out   Bangladesh              3     2       107.37
# 40    102         Out  West Indies              3     1       122.89
# 16    103     Not Out    Sri Lanka              4     3          NaN
#
#                             Venue         Column1   H/A        Date  \
# 31  Sher-e-Bangla Cricket Stadium           Dhaka  Away  19-02-2011
# 42         Sawai Mansingh Stadium          Jaipur  Home  16-10-2013
# 28  Sher-e-Bangla Cricket Stadium           Dhaka  Away   11/1/2010
# 40              Queen's Park Oval   Port of Spain  Away    5/7/2013
# 16    Galle International Stadium           Galle  Away  26-07-2017
#
#        Result Format Man of the Match Captain
# 31        Won    ODI               No      No
# 42        Won    ODI               No      No
# ...

# %%
a=data['Score'].max()
b=data["Score"].min()

# %%
print("Virat Kohli max score is:{0} and min score is:{1} ".format(a,b))
# Out:
# Virat Kohli max score is:254 and min score is:100

# %%
data.Score.sum()
# Out:
# 10081

# %%
data.rename(columns={ 'H/A':'Match_Mode'},inplace=True)

# %%
data.rename(columns={"Column1":"Location"},inplace=True)

# %%
data.head()
# Out:
#     Score Out/Not Out      Against  Batting Order  Inn.  Strike Rate  \
# 31    100     Not Out   Bangladesh              4     1       120.48
# 42    100     Not Out    Australia              3     2       192.30
# 28    102     Not Out   Bangladesh              3     2       107.37
# 40    102         Out  West Indies              3     1       122.89
# 16    103     Not Out    Sri Lanka              4     3          NaN
#
#                             Venue        Location Match_Mode        Date  \
# 31  Sher-e-Bangla Cricket Stadium           Dhaka       Away  19-02-2011
# 42         Sawai Mansingh Stadium          Jaipur       Home  16-10-2013
# 28  Sher-e-Bangla Cricket Stadium           Dhaka       Away   11/1/2010
# 40              Queen's Park Oval   Port of Spain       Away    5/7/2013
# 16    Galle International Stadium           Galle       Away  26-07-2017
#
#        Result Format Man of the Match Captain
# 31        Won    ODI               No      No
# ...

# %%
Away=data[data["Match_Mode"] == "Away"]
Away
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 31    100     Not Out    Bangladesh              4     1       120.48
# 28    102     Not Out    Bangladesh              3     2       107.37
# 40    102         Out   West Indies              3     1       122.89
# 16    103     Not Out     Sri Lanka              4     3          NaN
# 22    103         Out       England              4     3          NaN
# 10    103         Out     Sri Lanka              4     2          NaN
# 65    104         Out     Australia              3     2        92.85
# 5     105     Not Out   New Zealand              4     4          NaN
# 38    106         Out     Sri Lanka              3     1        93.80
# 51    106         Out     Australia              3     2       115.21
# 32    107         Out       England              4     1       115.05
# 48    107         Out      Pakistan              3     1        84.90
# ...

# %%
Away.Score.sum()
# Out:
# 5066

# %%
Away.Score.mean()
# Out:
# 123.5609756097561

# %%
Away_High_Score=Away.Score.sort_values()

# %%
Away_High_Score
# Out:
# 31    100
# 28    102
# 40    102
# 16    103
# 22    103
# 10    103
# 65    104
# 5     105
# 51    106
# 38    106
# 32    107
# 48    107
# 36    108
# 56    110
# 54    111
# 59    112
# 71    113
# 69    114
# 6     115
# 41    115
# 0     116
# 50    117
# 4     119
# 68    120
# 75    121
# 70    122
# 24    123
# 44    123
# 39    128
# 61    129
# 55    131
# 35    133
# 45    136
# 7     141
# 9     147
# 21    149
# 20    153
# 60    160
# 8     169
# 37    183
# 11    200
# Name: Score, dtype: int64

# %%
Away_Result_sum=Away.Result.value_counts()
Away_Result_sum
# Out:
# Won           24
# Lost          10
# Drawn          5
# Won (D/L)      1
# Lost (D/L)     1
# Name: Result, dtype: int64

# %%
Home=data[data["Match_Mode"] == "Home"]
Home
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 42    100     Not Out     Australia              3     2       192.30
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 17    104     Not Out     Sri Lanka              4     3          NaN
# 30    105         Out   New Zealand              3     1       100.96
# 27    107         Out     Sri Lanka              4     2        93.85
# 64    107         Out   West Indies              3     2        89.91
# 3     107         Out     Australia              5     2          NaN
# 33    112     Not Out       England              4     2       114.28
# 72    113         Out     Sri Lanka              3     1       129.89
# 58    113         Out   New Zealand              3     1       106.60
# 43    115     Not Out     Australia              3     2       174.24
# ...

# %%
Home.Score.sum()
# Out:
# 5015

# %%
Home_Result_sum=Home.Result.value_counts()
Home_Result_sum
# Out:
# Won      27
# Drawn     4
# Lost      3
# Tied      1
# Name: Result, dtype: int64
