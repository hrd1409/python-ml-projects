# %% [markdown]
# <a href="https://colab.research.google.com/github/hrd1409/python-ml-projects/blob/master/Customer_complaint_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
import nltk
import re
from nltk.corpus import stopwords
import string

# %% [markdown]
# dataset loading

# %%
data = pd.read_csv("consumercomplaints.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0 Date received  \
# 0           0    2022-11-11
# 1           1    2022-11-23
# 2           2    2022-11-16
# 3           3    2022-11-15
# 4           4    2022-11-07
# 5           5    2022-11-13
# 6           6    2022-11-07
# 7           7    2022-11-11
# 8           8    2022-11-09
# 9           9    2022-11-20
#
#                                              Product  \
# 0                                           Mortgage
# 1  Credit reporting, credit repair services, or o...
# 2                                           Mortgage
# 3                        Checking or savings account
# 4                                           Mortgage
# 5  Credit reporting, credit repair services, or o...
# 6  Credit reporting, credit repair services, or o...
# 7                        Credit card or prepaid card
# 8                        Credit card or prepaid card
# 9  Credit reporting, credit repair services, or o...
#
#                                   Sub-product  \
# ...

# %% [markdown]
# Analyzing the dataset

# %%
data.shape
# Out:
# (542685, 7)

# %%
data.size
# Out:
# 3798795

# %%
data.ndim
# Out:
# 2

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                           0
# Date received                        0
# Product                              0
# Sub-product                       4361
# Issue                                0
# Sub-issue                        46395
# Consumer complaint narrative    335251
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date received', 'Product', 'Sub-product', 'Issue',
#        'Sub-issue', 'Consumer complaint narrative'],
#       dtype='object')

# %%
data['Product'].value_counts()
# Out:
# Product
# Credit reporting, credit repair services, or other personal consumer reports    372268
# Debt collection                                                                  51930
# Credit card or prepaid card                                                      31457
# Checking or savings account                                                      27169
# Mortgage                                                                         25147
# Money transfer, virtual currency, or money service                                9372
# Student loan                                                                      7377
# Vehicle loan or lease                                                             6543
# Payday loan, title loan, or personal loan                                         4520
# Credit reporting                                                                  2607
# Bank account or service                                                           1715
# ...

# %%
data.dropna()
# Out:
#         Unnamed: 0 Date received  \
# 3                3    2022-11-15
# 11              11    2022-11-09
# 15              15    2022-11-14
# 51              51    2022-10-12
# 72              72    2022-10-09
# ...            ...           ...
# 542674      542674    2021-09-14
# 542677      542677    2019-11-08
# 542678      542678    2019-03-04
# 542679      542679    2019-03-02
# 542681      542681    2020-05-23
#
#                                                   Product       Sub-product  \
# 3                             Checking or savings account  Checking account
# 11                                        Debt collection        Other debt
# 15      Credit reporting, credit repair services, or o...  Credit reporting
# 51      Credit reporting, credit repair services, or o...  Credit reporting
# 72      Credit reporting, credit repair services, or o...  Credit reporting
# ...                                                   ...               ...
# ...

# %%
data.shape
# Out:
# (542685, 7)

# %% [markdown]
# NLP

# %%
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
stopword=set(stopwords.words('english'))

def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
data["Consumer complaint narrative"] = data["Consumer complaint narrative"].apply(clean)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data = data[["Consumer complaint narrative", "Product"]]
x = np.array(data["Consumer complaint narrative"])
y = np.array(data["Product"])

cv = CountVectorizer()
X = cv.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.33,
                                                    random_state=42)

# %%
sgdmodel = SGDClassifier()
sgdmodel.fit(X_train,y_train)
# Out:
# SGDClassifier()

# %%
user = input("Enter a Text: ")
data = cv.transform([user]).toarray()
output = sgdmodel.predict(data)
print(output)
# Out:
# Enter a Text: i am not able to pay 100$ to my brother through online Paypal account for his birthday celebration
# ['Credit reporting, credit repair services, or other personal consumer reports']
